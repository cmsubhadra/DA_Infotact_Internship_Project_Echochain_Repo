# %% [markdown]
# Check the Gold table size

# %%
# %sql
SELECT COUNT(*) AS total_rows
FROM workspace.default.gold_echochain_analytics;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_rows</th></tr></thead><tbody><tr><td>100</td></tr></tbody></table></div>

# %% [markdown]
# Check NULL Values

# %%
# %sql
SELECT
    COUNT(*) AS total_rows,
    COUNT_IF(sku IS NULL) AS null_sku,
    COUNT_IF(listing_id IS NULL) AS null_listing_id,
    COUNT_IF(secondary_market_depreciation IS NULL) AS null_depreciation,
    COUNT_IF(total_component_cost IS NULL) AS null_component_cost,
    COUNT_IF(weighted_failure_cost IS NULL) AS null_failure_cost,
    COUNT_IF(component_reliability_score IS NULL) AS null_reliability,
    COUNT_IF(resale_retention_score IS NULL) AS null_retention,
    COUNT_IF(circularity_score IS NULL) AS null_circularity
FROM workspace.default.gold_echochain_analytics;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_rows</th><th>null_sku</th><th>null_listing_id</th><th>null_depreciation</th><th>null_component_cost</th><th>null_failure_cost</th><th>null_reliability</th><th>null_retention</th><th>null_circularity</th></tr></thead><tbody><tr><td>100</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# Check Duplicate Records

# %%
# %sql
SELECT
    listing_id,
    COUNT(*) AS record_count
FROM workspace.default.gold_echochain_analytics
GROUP BY listing_id
HAVING COUNT(*) > 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>listing_id</th><th>record_count</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Validate Score Ranges

# %%
# %sql
SELECT
    COUNT(*) AS invalid_score_records
FROM workspace.default.gold_echochain_analytics
WHERE weighted_score < 0
   OR component_reliability_score < 0
   OR resale_retention_score < 0
   OR circularity_score < 0;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>invalid_score_records</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

# %% [markdown]
# Validate Secondary Market Depreciation

# %%
# %sql
SELECT
    MIN(secondary_market_depreciation) AS min_depreciation,
    MAX(secondary_market_depreciation) AS max_depreciation,
    AVG(secondary_market_depreciation) AS avg_depreciation
FROM workspace.default.gold_echochain_analytics;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>min_depreciation</th><th>max_depreciation</th><th>avg_depreciation</th></tr></thead><tbody><tr><td>33.69565217391305</td><td>97.58064516129032</td><td>57.13945009491693</td></tr></tbody></table></div>

# %% [markdown]
# Validate Circularity Score

# %%
# %sql
SELECT
    MIN(circularity_score) AS min_circularity_score,
    MAX(circularity_score) AS max_circularity_score,
    AVG(circularity_score) AS avg_circularity_score
FROM workspace.default.gold_echochain_analytics;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>min_circularity_score</th><th>max_circularity_score</th><th>avg_circularity_score</th></tr></thead><tbody><tr><td>43.62</td><td>76.15</td><td>65.0848</td></tr></tbody></table></div>

# %% [markdown]
# Validate Component-Level Metrics

# %%
# %sql
SELECT
    MIN(total_component_cost) AS min_component_cost,
    MAX(total_component_cost) AS max_component_cost,
    AVG(total_component_cost) AS avg_component_cost,

    MIN(weighted_failure_cost) AS min_failure_cost,
    MAX(weighted_failure_cost) AS max_failure_cost,
    AVG(weighted_failure_cost) AS avg_failure_cost,

    MIN(component_reliability_score) AS min_reliability_score,
    MAX(component_reliability_score) AS max_reliability_score,
    AVG(component_reliability_score) AS avg_reliability_score
FROM workspace.default.gold_echochain_analytics;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>min_component_cost</th><th>max_component_cost</th><th>avg_component_cost</th><th>min_failure_cost</th><th>max_failure_cost</th><th>avg_failure_cost</th><th>min_reliability_score</th><th>max_reliability_score</th><th>avg_reliability_score</th></tr></thead><tbody><tr><td>34500.0</td><td>73600.0</td><td>51770.5</td><td>4065.217391304348</td><td>8671.969696969698</td><td>6497.160356311727</td><td>82.98</td><td>89.1</td><td>87.30909999999999</td></tr></tbody></table></div>

# %% [markdown]
# Validate Resale Retention Score

# %%
# %sql
SELECT
    MIN(resale_retention_score) AS min_retention_score,
    MAX(resale_retention_score) AS max_retention_score,
    AVG(resale_retention_score) AS avg_retention_score
FROM workspace.default.gold_echochain_analytics;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>min_retention_score</th><th>max_retention_score</th><th>avg_retention_score</th></tr></thead><tbody><tr><td>2.4193548387096775</td><td>66.30434782608695</td><td>42.86054990508308</td></tr></tbody></table></div>

# %% [markdown]
# Final Gold Table Integrity Check

# %%
# %sql
SELECT
    COUNT(*) AS total_rows,
    COUNT(DISTINCT sku) AS unique_skus,
    COUNT(DISTINCT listing_id) AS unique_listings
FROM workspace.default.gold_echochain_analytics;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_rows</th><th>unique_skus</th><th>unique_listings</th></tr></thead><tbody><tr><td>100</td><td>30</td><td>100</td></tr></tbody></table></div>

# %% [markdown]
# ### Final Validation Summary
# ### Gold table validation completed successfully.
#
# ### Total records: 100
# ### Unique SKUs: 30
# ### Unique marketplace listings: 100
# ### NULL validation: Passed
# ### Duplicate listing validation: Passed
# ### Score range validation: Passed
# ### Secondary market depreciation validation: Passed
# ### Circularity score validation: Passed
# ### Component metrics validation: Passed
# ### Resale retention score validation: Passed
# ### The Gold analytics table is ready for downstream Power BI analysis.
